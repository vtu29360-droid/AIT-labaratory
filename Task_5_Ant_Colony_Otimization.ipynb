# %% [markdown]
# <a href="https://colab.research.google.com/github/vtu29360-droid/AIT-labaratory/blob/main/Task_5_Ant_Colony_Otimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
R1 = float(input("Enter pheromone value R1: "))
R2 = float(input("Enter pheromone value R2: "))
total = R1+R2
P1 = R1/total
P2 = R2/total
print("probability of path 1=",P1)
print("probability of path 2=",P2)
if P1>P2:
  print("Ant prefers path 1")
elif P1<P2:
  print("Ant prefers path 2")
else:
  print("Both paths have equal probability")
print("P1+P2 =",P1+P2)
# Out:
# Enter pheromone value R1: 30
# Enter pheromone value R2: 70
# probability of path 1= 0.3
# probability of path 2= 0.7
# Ant prefers path 2
# P1+P2 = 1.0
